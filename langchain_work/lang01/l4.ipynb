# %% [markdown]
# ### MESSAGES

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.3-70b-versatile",temperature=0)
model.invoke("How are you?")
# Out:
# AIMessage(content="I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 39, 'total_tokens': 85, 'completion_time': 0.104665852, 'completion_tokens_details': None, 'prompt_time': 0.002967461, 'prompt_tokens_details': None, 'queue_time': 0.163558928, 'total_time': 0.107633313}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ea163-7d15-7a41-bf38-2e778538416e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 46, 'total_tokens': 85})

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage, ToolMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on python")
]

resp = model.invoke(messages)
resp.content
# Out:
# "In twisted coils, a serpent lies,\nPython, a name that meets the eyes,\nA language born of code and art,\nA symphony that beats within the heart.\n\nWith indentation, a gentle guide,\nIt weaves a tapestry, side by side,\nLoops and functions, a wondrous spin,\nA dance of logic, locked within.\n\nIn realms of data, it reigns supreme,\nA master of lists, a king of dreams,\nIt tames the chaos, brings order to sight,\nA beacon in the dark of endless night.\n\nWith libraries, a treasure to share,\nIt opens doors, to secrets rare,\nNumPy, Pandas, and scikit-learn too,\nA trio of heroes, to see us through.\n\nIn machine learning, it finds its throne,\nA sovereign of algorithms, all its own,\nIt learns, adapts, and grows with each new test,\nA shining star, that forever finds its best.\n\nOh, Python, dear Python, a poet's friend,\nA partner in code, till the very end,\nTogether we'll weave, a tapestry so fine,\nA dance of ones and zeros, a symphony divine."

# %%
human_msg = HumanMessage(
    content="Hello!",
    name="BOB",
    id="msg_1"
)

resp = model.invoke([human_msg])
resp.content
# Out:
# "Hello. It's nice to meet you. Is there something I can help you with or would you like to chat?"

# %%
ai_msg = AIMessage("I would like to assist you!!")

message = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,
    HumanMessage("Great what is 2+3")
]

print(message)

resp = model.invoke(message)
print(resp)

resp.usage_metadata
# Out:
# [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Can you help me?', additional_kwargs={}, response_metadata={}), AIMessage(content='I would like to assist you!!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Great what is 2+3', additional_kwargs={}, response_metadata={})]
# ...

# %%
ai_msg = AIMessage(
    content = [],
    tool_calls = [{
        "name": "getWeather",
        "args": {"location": "Delhi"},
        "id": "call_1"
    }]
)

weather_result = "Sunny, 72C"
tool_msg = ToolMessage(
    content=weather_result,
    tool_call_id = "call1"
)

msg = [
    HumanMessage("What is the weather in Delhi"),
    ai_msg,
    tool_msg
]

resp = model.invoke(msg)
resp.content
# Out:
# 'The current weather in Delhi is sunny with a temperature of 72°C (or 161.6°F). However, please note that weather conditions can change rapidly and may vary depending on the time of day, season, and other factors. For the most up-to-date and accurate weather information, I recommend checking a reliable weather forecasting website or app.'
